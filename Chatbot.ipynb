# %% [markdown]
# # Importing The Neccesary Libraries

# %%
import nltk
import json
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import random
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Creating Query-Based Intents for the Dataset

# %%
intents = {
  "intents": [


    {
        "tag": "greeting",
        "patterns": ["Hi", "Hello", "Hey", "Good day", "How are you?"],
        "responses": ["Hello!", "Good to see you!", "Hi there, how can I help?"],
        "context_set": ""
      },
      {
        "tag": "farewell",
        "patterns": ["Goodbye", "Bye", "See you later", "Talk to you later"],
        "responses": ["Sad to see you go :(", "Goodbye!", "Come back soon!"],
        "context_set": ""
      },
      {
        "tag": "creator",
        "patterns": ["Who created you?", "Who is your developer?", "Who made you?","who designed you","who built you"],
        "responses": ["I was created by Mrcet Computational Intelligence Department."],
        "context_set": ""
      },
      {
        "tag": "identity",
        "patterns": ["What is your name?", "What should I call you?", "Who are you?"],
        "responses": ["You can call me Mrcet chatbot. I'm a Chatbot."],
        "context_set": ""
      },
      {
        "tag": "hours",
        "patterns": ["What are the college timings?", "When is the college open?", "What are your hours of operation?","College Timings"],
        "responses": ["The college is open from 9.20am to 3.30pm, Monday to Saturday."],
        "context_set": ""
      },
      {
        "tag": "timings",
        "patterns": ["Lunch break?", "When is the break?", "What are timings of Bio break?","bio break?"],
        "responses": ["The lunch break is for 1hr 12.30pm to 1.30pm","Bio break for 10m (10.20am to 10.30pm)"],
        "context_set": ""
      },
      {
        "tag": "library",
        "patterns": ["Does the college have a library?", "Where is the library located?", "What are the library timings?"],
        "responses": ["Yes, the college has a library. The library is located at placement block 3rd floor. The timings are from 9am to 5pm, Monday to saturday."],
        "context_set": ""
      },
      {

            "tag": "about_college and mrcet",
            "patterns": ["Tell me about the college", "What is MRCET?", "Give me information about MRCET"],
            "responses": [
              "Malla Reddy College of Engineering & Technology (MRCET) is a constituent College of Malla Reddy Group of Institutions (MRGI) established in 2004. The College offers Engineering courses (B.Tech.) in AE, CSE, CSE(AI&ML), CSE(CS), CSE(IOT), CSE(DS), AI&ML, AI&DS, ECE, EEE, IT, MECH disciplines and Post Graduate (M.Tech.) courses in ECE, CSE, MECH and AE specializations in addition to MBA programmes. The College campus with its aboriculture and horticulture is situated away from the hustle and bustle of the city, providing a serene and tranquil atmosphere, which is conducive to both teaching and learning processes."
            ],
            "context_set": ""
          },
          {
            "tag": "approvals",
            "patterns": ["What are the approvals of MRCET?", "Is MRCET approved?", "Accreditations of MRCET","Autonomous or not","is Mrcet Autonomous","Mrcet is Autonomous"],
            "responses": [
              "YES MRCET is an Autonomous Institution recognized by UGC, Govt. of INDIA. It is approved by AICTE, Govt. of India, New Delhi, and permanently affiliated to JNTUH, Hyderabad. The college is accredited by NBA, New Delhi, India, and NAAC with A-GRADE, UGC, New Delhi. It is also an ISO 9001:2015 Certified Institution and approved by the Govt. of Telangana, India. Additionally, MRCET is a UGC 2f & 12(B) recognized institution, UGC New Delhi."
            ],
            "context_set": ""
          },
          {
            "tag": "special_achievements",
            "patterns": ["What are the special achievements of MRCET?", "MRCET achievements", "Achievements of MRCET"],
            "responses": [
              "MRCET has achieved several milestones: It is an Autonomous Institution recognized by UGC, Govt. of INDIA, accredited by NBA (Tier-1), AICTE, New Delhi, and NAAC-A Grade, UGC, Govt. of India. It is also ISO 9001:2015 Certified, has 2(f) & 12(B) Recognition from UGC, Govt. of India, and its NSS Unit is recognized by JNTUH, Hyderabad. MRCET has a Research Centre Status from JNTUH, Hyderabad, MoU with NRDC, Govt. of India, and an AICTE-MHRD Institution Innovation Council, Ministry of HRD, Govt. of India. The college has an Industry Institute Partnership Cell (IIPC), recognition of Scientific Industrial Research Organizations (SIROs) by Govt. of India, and is a life member of NHRD Network. MRCET is a CISCO International Certification Authorized Centre, approved to admit Foreign Students/PIO’s, a Nodal Center for IIT - Bombay/Kharagpur for Technology Transfer, and a NASSCOM Nodal Center for NAC - Test Assessment. It also houses a Business Incubation Centre - MSME, Govt. of India, and a Global Education and Career Counseling Centre."
            ],
            "context_set": ""
          },
          {
            "tag": "management_founder_chairman",
            "patterns": ["Who is the founder chairman?", "Tell me about the founder chairman", "Founder chairman of MRCET"],
            "responses": [
              "Shri CH. Malla Reddy, the most humble, dynamic, and charismatic founder chairman, is a visionary who brought about a revolution in the field of education. He is the avant-garde (pioneer) in creating numerous avenues which made professional and technical education accessible to young aspirants. Under his esteemed leadership, the campus has grown by leaps and bounds to become a major learning center with 14 institutes offering almost all Engineering, Management, Computers, and Pharmacy courses. Two hospitals, namely Narayana Hrudayalaya and Malla Reddy Cardiology Hospital, are functioning in Malla Reddy Health City. His life has rekindled many lives by not only igniting their dreams but also by accomplishing them. He strongly believes that only education can bring across a positive change in society."
            ],
            "context_set": ""
          },
          {
            "tag": "management_secretary",
            "patterns": ["Who is the secretary?", "Tell me about the secretary", "Secretary of MRCET","Who is the secretary of mrcet?"],
            "responses": [
              "Shri CH. Mahender Reddy, the Secretary of MRCET, emphasizes the importance of professional education in the rapidly advancing technological era. He believes that choosing the right college is crucial for one's career journey. At MRCET, the focus has always been on imparting quality education in various engineering disciplines. Over the past seven years, significant efforts have been made to establish MRCET as one of the best engineering institutes in the country. The faculty members are carefully selected and continuously updated on recent technical innovations. The atmosphere at MRCET is friendly, cordial, and perfectly suited to the all-round development of students."
            ],
            "context_set": ""
          },
          {
            "tag": "management_treasurer",
            "patterns": ["Who is the treasurer?", "Tell me about the treasurer", "Treasurer of MRCET"],
            "responses": [
              "Dr. Ch. Bhadra Reddy, the Treasurer of MRGI, is a highly qualified professional with an M.D. degree in medicine. His youthful presence and proactive approach contribute to shaping the destiny of the student community by imparting quality education in a conducive environment, thereby motivating the students to successfully meet the contemporaneous needs of the industry."
            ],
            "context_set": ""
          },
          {
            "tag": "management_advisor",
            "patterns": ["Who is the advisor?", "Tell me about the advisor", "Advisor of MRCET"],
            "responses": [
              "Dr. V.S.K. Reddy, the Advisor of Malla Reddy College of Engineering & Technology, has more than 19 years of experience in teaching and industry. An alumnus of IIT Kharagpur, he obtained a Ph.D. in the area of Multi-media Signal Processing and Communication Protocols. He specializes in Electronics & Communications and Computer Science Engineering. Dr. Reddy has over 45 publications in national and international conferences and journals. He is a fellow of IETE, a life member of ISTE, and a member of IEEE. He was awarded 'Best Teacher' for three consecutive academic years with citation and cash award and received the 'India Jewel Award' for outstanding contributions in engineering and technology research."
            ],
            "context_set": ""
          },
          {
            "tag": "management_principal",
            "patterns": ["Who is the principal?", "Tell me about the principal", "Principal of MRCET","Who is the principal? of mrcet"],
            "responses": [
              "Dr. S Srinivasa Rao, the Principal of MRCET, completed his B.Tech in Electronics & Communication Engineering from Madras Institute of Technology, Chennai. He did his M.Tech in Digital Systems & Computer Electronics from JNTU College of Engineering, Hyderabad, and his Ph.D. from JNTU University, Hyderabad, in Wireless Communications. With 25 years of teaching experience in various reputed engineering colleges in AP & Telangana, Dr. Rao has published more than 20 research papers in international journals and presented 30 research papers in international/national conferences/seminars/symposiums. He has also conducted various workshops, seminars, conferences, and FDPs."
            ],
            "context_set": ""
          },
          {
            "tag": "management_dean_students_welfare and dean",
            "patterns": ["who is dean","who is dean of mrcet","who is the dean of mrcet","who is the dean","Who is the dean of student welfare?", "Tell me about the dean of student welfare", "Dean of student welfare at MRCET"],
            "responses": [
              "Dr. Tipirneni Venugopal, the Dean of Students Welfare, received his Bachelor of Engineering degree in Electronics Engineering from Marathwada University and a Master of Technology in Digital Systems and Computer Electronics from JNTUH. He obtained his Ph.D. in Digital Image Processing and is a member of the Institution of Engineers, ISTE, and IETE. With more than 30 years of experience in teaching, administration, and research, Dr. Venugopal has published five research papers in national and international journals and conferences. He has organized national conferences, faculty development programs, seminars, guest lectures, and attended around ten FDPs and workshops. He established a Training Technology Display and Dissemination Center for the display, demonstration, and training of DAE technologies, which is the only one in Telangana state out of ten in India, sponsored by Bhabha Atomic Research Center (BARC) Mumbai, with a sanctioned amount of 37.5 lakhs."
            ],
            "context_set": ""
          },
          {
            "tag": "principal_profile",
            "patterns": [
              "Tell me about the principal's profile",
              "Principal's brief profile",
              "Who is the principal of MRCET?",
              "Can you provide details about Dr. S Srinivasa Rao?",
              "Who is Dr. S Srinivasa Rao?",
              "Principal's experience",
              "Principal's career",
              "Principal's achievements",
              "Principal's work history"
            ],
            "responses": [
              "Dr. S Srinivasa Rao is the Principal of Malla Reddy College of Engineering & Technology. He has 25 years of teaching experience in various reputed engineering colleges in Andhra Pradesh & Telangana. He has published more than 20 research papers in international journals and presented 30 research papers in international/national conferences, seminars, and symposiums. He has also conducted various workshops, seminars, conferences, and faculty development programs (FDPs).",
              "Dr. S Srinivasa Rao has a distinguished career with 25 years of teaching experience in reputed engineering colleges in AP & Telangana. He has published over 20 research papers in international journals and presented 30 research papers at international/national conferences, seminars, and symposiums.",
              "Dr. S Srinivasa Rao's extensive experience in academia includes conducting numerous workshops, seminars, conferences, and faculty development programs (FDPs). He has also published over 20 research papers in international journals and presented 30 research papers in various academic forums.",
              "With 25 years of teaching experience and numerous academic contributions, Dr. S Srinivasa Rao has significantly impacted the field of engineering education in Andhra Pradesh & Telangana."
            ],
            "context_set": ""
          },
          {
            "tag": "principal_qualifications",
            "patterns": [
              "What are the qualifications of the principal?",
              "Principal's academic background",
              "Principal's education",
              "Principal's qualifications",
              "What degrees does Dr. S Srinivasa Rao hold?",
              "Principal's academic profile",
              "Dr. S Srinivasa Rao's qualifications"
            ],
            "responses": [
              "Dr. S Srinivasa Rao completed his B.Tech in Electronics & Communication Engineering from Madras Institute of Technology, Chennai, one of the top engineering colleges in India. He earned his M.Tech in Digital Systems & Computer Electronics from JNTU College of Engineering, Hyderabad, and his Ph.D. in Wireless Communications from JNTU University, Hyderabad.",
              "Dr. S Srinivasa Rao holds the following qualifications:\n- Ph.D. in ECE from JNTU Hyderabad (2013)\n- M.Tech in DSCE from JNTU Hyderabad (2004) with 82% marks\n- B.Tech in ECE from Madras Institute of Technology, Anna University (1989) with 68.25% marks\n- B.Sc in Physics from Nagarjuna University (1986) with 83.25% marks\n- Inter in M.P.C from BIE, Hyderabad, A.P (1983) with 72.6% marks\n- S.S.C from BSE, Hyderabad, A.P (1981) with 70.6% marks",
              "Dr. S Srinivasa Rao has an impressive academic profile:\n- Ph.D. in ECE from JNTU Hyderabad (2013)\n- M.Tech in DSCE from JNTU Hyderabad (2004) with 82% marks\n- B.Tech in ECE from Madras Institute of Technology, Anna University (1989) with 68.25% marks\n- B.Sc in Physics from Nagarjuna University (1986) with 83.25% marks\n- Inter in M.P.C from BIE, Hyderabad, A.P (1983) with 72.6% marks\n- S.S.C from BSE, Hyderabad, A.P (1981) with 70.6% marks",
              "Dr. S Srinivasa Rao has achieved several academic milestones:\n- Secured University Fourth Rank in B.Sc\n- Selected for National Merit Scholarship\n- Secured University Second Rank in M.Tech\n- Qualified ASOC, Government of India, Amateur Section, W.P.C. Wing, Ministry of Communications & IT, New Delhi"
            ],
            "context_set": ""
          },
          {
            "tag": "admission_procedure",
            "patterns": [
                "How can i get admission?",
              "how to get into mrcet?",
              "How do I apply for admission?",
              "What is the admission process?",
              "How can I get admitted to MRCET?",
              "Admission procedure for MRCET",
              "What is the process to apply to MRCET?",
              "How to apply for admission?"
            ],
            "responses": [
              "Admissions to the Institute are made along with other engineering colleges in the state through a common entrance test conducted by the Govt. of Telangana / Andhra Pradesh.",
              "To apply for admission, students need to take a common entrance test conducted by the Govt. of Telangana / Andhra Pradesh. The application form can be downloaded from the website and submitted in person.",
              "The admission procedure involves a common entrance test conducted by the state government, followed by the submission of the application form, which can be downloaded from the website."
            ],
            "context_set": ""
          },
          {
            "tag": "eligibility_btech",
            "patterns": [
                "eligibility of Btech?",
                "eligibility into Btech?",
              "What is the eligibility criteria for B.Tech?",
              "B.Tech admission requirements",
              "Who can apply for B.Tech?",
              "Eligibility for B.Tech courses",
              "What are the criteria for B.Tech admission?"
            ],
            "responses": [
              "70% of the seats are allotted based on the merit in the Engineering and Medical Common Entrance Test (EAMCET) conducted by Govt. of Telangana / Andhra Pradesh. 30% of the seats are earmarked for Management / NRI candidates.",
              "For B.Tech courses, 70% of seats are filled through EAMCET merit, while 30% are reserved for Management / NRI candidates.",
              "Diploma holders can be admitted to the second year of B.Tech under the lateral entry scheme, which accounts for 20% of the intake, based on the merit in the Engineering Common Entrance Test (ECET) conducted by Govt. of Telangana / Andhra Pradesh."
            ],
            "context_set": ""
          },
          {
            "tag": "eligibility_mtech",
            "patterns": [
              "What is the eligibility criteria for M.Tech?",
              "M.Tech admission requirements",
              "Who can apply for M.Tech?",
              "Eligibility for M.Tech courses",
              "What are the criteria for M.Tech admission?"
            ],
            "responses": [
              "The eligibility criteria for M.Tech courses vary by specialization:\n- Aerospace Engineering: B.E / B.Tech in Aeronautical Engineering / Mechanical Engineering (or) Equivalent with valid GATE score / based on the rank obtained in the test conducted by JNTU.\n- Computer Science & Engineering: B.E / B.Tech in Computer Science and Engineering (or) Equivalent with valid GATE score / based on the rank obtained in the test conducted by JNTU.\n- Systems & Signal Processing: B.E / B.Tech in ECE / EEE / CSE / IT / EIE (or) Equivalent with valid GATE score / based on the rank obtained in the test conducted by JNTU.\n- Machine Design: B.E / B.Tech in Mechanical Engineering / Automobile Engineering / Mechatronics / Aeronautical Engineering (or) Equivalent with valid GATE score / based on the rank obtained in the test conducted by JNTU."
            ],
            "context_set": ""
          },
          {
            "tag": "eligibility_mba",
            "patterns": [
              "What is the eligibility criteria for MBA?",
              "MBA admission requirements",
              "Who can apply for MBA?",
              "Eligibility for MBA courses",
              "What are the criteria for MBA admission?"
            ],
            "responses": [
              "The minimum qualification for admission to the first year of the MBA is a pass in an undergraduate course (10 + 2 + 3). 70% of the seats are allotted based on the merit in the Integrated Common Entrance Test (ICET) conducted by Govt. of Telangana / Andhra Pradesh. 30% of the seats are earmarked for Management / NRI candidates."
            ],
            "context_set": ""
          },
          {
            "tag": "how_to_apply",
            "patterns": [
              "How to apply?",
              "How can I apply for admission?",
              "Application process",
              "Steps to apply",
              "Where can I find the application form?"
            ],
            "responses": [
              "To apply, download the application form from the MRCET website. Fill in the form and submit it in person. 30% of seats in each branch are filled under Management Quota based on eligibility as per JNTU rules. 70% of seats are filled from Government.",
              "You can download the application form from the website, fill it in, and submit it in person. 70% of the seats are filled by the government, while 30% are reserved for the Management Quota."
            ],
            "context_set": ""
          },
          {
            "tag": "contact_details",
            "patterns": [
              "How can I contact MRCET?",
              "Contact information",
              "Phone number for admission",
              "Email for admission",
              "Admission office contact"
            ],
            "responses": [
              "For more details, please contact:\nPhone Number: 7207034237\nEmail ID: mrcet2004@gmail.com",
              "You can reach out to the admission office at:\nPhone Number: 7207034237\nEmail ID: mrcet2004@gmail.com"
            ],
            "context_set": ""
          },
          {
            "tag": "undergraduate_courses",
            "patterns": [
              "What are the undergraduate courses offered?",
              "List the B.Tech courses available.",
              "What are the UG courses at MRCET?",
              "Tell me about the B.Tech programmes.",
              "What B.Tech specializations does MRCET offer?"
            ],
            "responses": [
              "Malla Reddy College of Engineering and Technology offers the following undergraduate courses with the respective annual intake:\n\n1. **B.Tech – Computer Science and Engineering**: 420\n2. **B.Tech – Computer Science and Engineering (Artificial Intelligence and Machine Learning)**: 300\n3. **B.Tech – Computer Science and Engineering (Data Science)**: 240\n4. **B.Tech – Computer Science and Engineering (Cyber Security)**: 60\n5. **B.Tech – Computer Science and Information Technology**: 60\n6. **B.Tech – Electronics and Communication Engineering**: 120\n7. **B.Tech – Electrical and Electronics Engineering**: 30\n8. **B.Tech – Aeronautical Engineering**: 60\n9. **B.Tech – Mechanical Engineering**: 30"
            ],
            "context_set": ""
          },
          {
            "tag": "postgraduate_courses",
            "patterns": [
              "What are the postgraduate courses offered?",
              "List the M.Tech courses available.",
              "What are the PG courses at MRCET?",
              "Tell me about the M.Tech programmes.",
              "What M.Tech specializations does MRCET offer?"
            ],
            "responses": [
              "Malla Reddy College of Engineering and Technology offers the following postgraduate courses (full-time) with the respective annual intake:\n\n1. **M.Tech – Computer Science and Engineering (CSE)**: 30\n2. **M.Tech – VLSI and Embedded Systems (ECE)**: 24\n3. **M.Tech – Aerospace Engineering (ANE)**: 30\n4. **M.Tech – Machine Design (MECH)**: 30\n5. **M.Tech – Thermal Engineering (MECH)**: 24"
            ],
            "context_set": ""
          },{
            "tag": "mba_courses",
            "patterns": [
              "What is the MBA course offered?",
              "List the MBA programme details.",
              "What are the details of the MBA course at MRCET?",
              "Tell me about the MBA programme.",
              "What is the intake for MBA at MRCET?"
            ],
            "responses": [
              "Malla Reddy College of Engineering and Technology offers the following Master of Business Administration (MBA) programme with an annual intake of 240."
            ],
            "context_set": ""
          },
          {
            "tag": "research_programmes",
            "patterns": [
              "What research programmes are offered?",
              "List the Ph.D. programmes available.",
              "What are the research opportunities at MRCET?",
              "Tell me about the Ph.D. programme.",
              "What is the Ph.D. course offered?"
            ],
            "responses": [
            "Malla Reddy College of Engineering and Technology offers the following research programme:\n\n1. **Ph.D - Electronics and Communication Engineering**"
            ],

            "context_set": ""
          },
          {
            "tag": "foreign_students_admission",
            "patterns": [
              "What is the admission procedure for foreign students?",
              "How can foreign students apply?",
              "Details on admissions for PIOs and foreign students.",
              "What are the seats reserved for foreign students?",
              "How do PIOs and foreign students get admission?"
            ],
            "responses": [
              "Foreign students and PIOs are admitted in a supernumerary quota."
            ],
            "context_set": ""
          },

    #courses and seats in take
    {
  "tag": "UG_Courses",
  "patterns": [
    "B.Tech – Computer Science and Engineering",
    "B.Tech seats Computer Science and Engineering",
    "B.Tech seats Cse",
    "B.Tech seats Ece",
    "B.Tech seats Eee",
    "B.Tech seats Cse-aiml",
    "B.Tech seats Cse-ds",
    "B.Tech seats Cse-cs",
    "B.Tech seats Cse-iot",
    "B.Tech seats Aiml",
    "B.Tech seats Aids",
    "B.Tech seats aero,aeronotical",
    "B.Tech seats mechanical,mech",
    "B.Tech – Computer Science and Engineering (Artificial Intelligence and Machine Learning)",
    "B.Tech – Computer Science and Engineering (Data Science)",
    "B.Tech – Computer Science and Engineering (Cyber Security)",
    "B.Tech – Computer Science and Information Technology",
    "B.Tech – Electronics and Communication Engineering",
    "B.Tech – Electrical and Electronics Engineering",
    "B.Tech – Aeronautical Engineering",
    "B.Tech – Mechanical Engineering"
  ],
  "responses": [
    "The intake for B.Tech – Computer Science and Engineering is 420",
    "The intake for B.Tech – Computer Science and Engineering (Artificial Intelligence and Machine Learning) is 300",
    "The intake for B.Tech – Computer Science and Engineering (Data Science) is 240",
    "The intake for B.Tech – Computer Science and Engineering (Cyber Security) is 60",
    "The intake for B.Tech – Computer Science and Information Technology is 60",
    "The intake for B.Tech – Electronics and Communication Engineering is 120",
    "The intake for B.Tech – Electrical and Electronics Engineering is 30",
    "The intake for B.Tech – Aeronautical Engineering is 60",
    "The intake for B.Tech – Mechanical Engineering is 30"
  ],
  "context_set": ""
},
{
  "tag": "PG_Courses",
  "patterns": [
    "M.Tech – Computer Science and Engineering",
    "M.Tech – VLSI and Embedded Systems",
    "M. Tech – Aerospace Engineering",
    "M.Tech – Machine Design",
    "M.Tech – Thermal Engineering"
  ],
  "responses": [
    "The intake for M.Tech – Computer Science and Engineering is 30",
    "The intake for M.Tech – VLSI and Embedded Systems is 24",
    "The intake for M. Tech – Aerospace Engineering is 30",
    "The intake for M.Tech – Machine Design is 30",
    "The intake for M.Tech – Thermal Engineering is 24"
  ],
  "context_set": ""
},
{
  "tag": "MBA_Course",
  "patterns": [
    "MBA – Master of Business Administration"
  ],
  "responses": [
    "The intake for MBA – Master of Business Administration is 240"
  ],
  "context_set": ""
},
{
  "tag": "PhD_Course",
  "patterns": [
    "Ph.D - Electronics and Communication Engineering"
  ],
  "responses": [
    "The Ph.D course is available for Electronics and Communication Engineering"
  ],
  "context_set": ""
},

    # hostel facilities
    {
  "tag": "MRCET_Hostel",
  "patterns": [
      "is hostel available at MRCET",
    "Is hostel available",
    "Hostel for students",
    "Hostel facilities at MRCET",
    "MRCET hostel services",
    "Boys and girls hostel at MRCET",
    "Hostel life at MRCET",
      "Hostel Fee"
  ],
  "responses": [
    "MRCET provides separate hostel buildings for boys and girls.",
    "Healthy and hygienic dining facilities are available at the hostel.",
    "The hostel has a purified water plant for clean drinking water.",
    "24x7 medical facilities and ambulance services are available for emergencies.",
    "The hostel is secured with 24x7 security and CCTV surveillance.",
    "There is 24x7 power backup and solar hot water provision in the hostel.",
    "Students can enjoy indoor and outdoor games in the hostel.",
    "A TV room is available for entertainment, and the campus is Wi-Fi enabled.",
    "The hostel maintains clean and green surroundings with regular housekeeping services.",
    "A waiting lounge area is also provided for comfort.",
    "Hostel fee is 90000 per annum."
  ],
  "context_set": ""
},


    # transport
    {
  "tag": "MRCET_Transport",
  "patterns": [
      "college bus",
    "Transport facilities at MRCET",
    "College bus services for students",
    "MRCET transport fee",
    "How to reach MRCET",
    "MRCET bus routes"
  ],
  "responses": [
    "MRCET provides transport facilities from various places in the city to the college.",
    "The transport fee is 40,000 rupees per year, regardless of the route or location within the city."
  ],
  "context_set": ""
},


    # Library
    {
  "tag": "MRCET_Library",
  "patterns": [
    "Library at MRCET",
    "MRCET learning resources",
    "Books availability at MRCET",
    "Library working hours at MRCET",
    "MRCET library policy"
  ],
  "responses": [
    "The MRCET library is well-stocked with standard textbooks and books by reputable authors across all fields taught at the college.",
    "The college follows a policy of purchasing multiple copies of books to ensure availability for a large number of students.",
    "There is no budget approval required when purchasing books, ensuring students have access to reference materials at all times.",
    "The library working hours are from 09:00 am to 05:30 pm, Monday to Saturday."
  ],
  "context_set": ""
},


    # sports
    {
  "tag": "MRCET_Sports_Center",
  "patterns": [
    "Sports facilities at MRCET",
    "Gymnasium at MRCET",
    "Games at MRCET sports center",
    "List of sports at MRCET",
    "MRCET sports center activities"
  ],
  "responses": [
    "MRCET offers a variety of sports and fitness facilities, including a well-equipped gymnasium.",
    "Students can enjoy playing volleyball at the sports center.",
    "Basketball courts are available for students at MRCET.",
    "The sports center also provides facilities for throw ball.",
    "Football is another popular sport available at MRCET.",
    "Kabbadi is one of the traditional sports offered at the college.",
    "Badminton courts are provided for students at MRCET.",
    "Cricket is a major sport at the MRCET sports center.",
    "Facilities for athletes are available to encourage participation in track and field events.",
    "Students can also engage in indoor games like chess.",
    "Table tennis is another indoor sport available at MRCET.",
    "Caroms is provided as a recreational indoor game.",
    "The college also has facilities for handball.",
    "Kho-kho is one of the traditional games offered at MRCET."
  ],
  "context_set": ""
},


    #placements

    {
  "tag": "MRCET_Placement_Statistics",
  "patterns": [
    "UG placement statistics at MRCET",
    "PG placement statistics at MRCET",
    "Placement details at MRCET",
    "MRCET median salary package",
    "Students opting for higher studies at MRCET"
  ],
  "responses": [
    "For UG (4 Years) placement statistics at MRCET, 956 students graduated and 766 students were placed.",
    "For PG (2 Years) placement statistics at MRCET, 55 students graduated and 45 students were placed.",
    "The average salary package for UG students is Rs. 5,10,000 per annum.",
    "The average salary package for PG students is Rs. 5,25,000 per annum.",
    "The median salary package for UG students is Rs. 5,10,000 per annum.",
    "The median salary package for PG students is Rs. 5,25,000 per annum.",
    "172 UG students opted for higher studies.",
    "8 PG students opted for higher studies."
  ],
  "context_set": ""
},

    #placement top recrutiers

    {
  "tag": "MRCET_Top_Recruiters",
  "patterns": [
    "Top recruiters at MRCET",
    "Companies hiring from MRCET",
    "MRCET placement recruiters",
    "Recruiters at MRCET Hyderabad",
    "MRCET top companies"
  ],
  "responses": [
    "Top recruiters at MRCET Hyderabad include:",
    "1. TCS",
    "2. Capgemini",
    "3. Deloitte",
    "4. IBM",
    "5. Amazon",
    "6. Infosys",
    "7. Mahindra"
  ],
  "context_set": ""
},

    #placement records

    {
  "tag": "MRCET_Placement_Records",
  "patterns": [
    "Top Placement sheet at MRCET",
    "History of Placement at MRCET",
    "MRCET placement recruiters",
    "Recruiters at MRCET Hyderabad",
    "MRCET top companies"
  ],
  "responses": [
    "There are Many students placed Every year for more deatils visit https://mrcet.com/StudentsPlaced.html"
  ],
  "context_set": ""
},

# Hods
    # h and S
    {
  "tag": "MRCET_Humanities_Sciences_HOD",
  "patterns": [
      "H&S Hod",
      "H and S Hod",
    "H&S department hod at MRCET",
    "Head of Humanities & Sciences at MRCET",
    "Who is the HOD of H&S at MRCET",
    "Contact details of H&S HOD MRCET"
  ],
  "responses": [
    "Dr. V. Madhusudhana Reddy is the Head of the Department (HOD) for Humanities & Sciences at MRCET.",
    "He holds M.Sc., M.Phil., and PhD degrees.",
    "You can contact him at +91-9492025025 or via email at v.madhusudhanareddy@gmail.com."
  ],
  "context_set": ""
},


    # aiml hod ci dept
    {
  "tag": "MRCET_CSE_AIML_HOD",
  "patterns": [
    "HOD of CSE AIML at MRCET",
    "HOD of AIML at MRCET",
    "HOD of AIDS at MRCET",
    "CSE AIML HOD ",
    "AIML HOD ",
    "AIDS HOD ",
    "CSE-AIML HOD ",
    "HOD of Computational Intelligence at MRCET",
    "HOD of Computational Intelligence",
    "CSE AIML HOD contact details",
    "Who is the head of AIML at MRCET",
    "Contact Dr. D. Sujatha at MRCET"
  ],
  "responses": [
    "Dr. D. Sujatha is the Head of the Department for CSE-AIML, AIML, and AI & Data Science at MRCET.",
    "She holds B.Tech, M.Tech, and Ph.D. degrees (JNTUH).",
    "You can contact her at +91-8978918912 or via email at sujatha.dandu@mrcet.ac.in."
  ],
  "context_set": ""
},

# iot cs ds hod
    {
  "tag": "MRCET_Emerging_Technologies_HOD",
  "patterns": [
      "HOD of IOT",
      "HOD of data science",
      "HOD of cyber security",
    "HOD of Emerging Technologies at MRCET",
    "IoT, Cybersecurity, Data Science HOD at MRCET",
    "Contact Dr. M.V. Kamal at MRCET",
    "MRCET HOD for IoT, Cybersecurity, Data Science"
  ],
  "responses": [
    "Dr. M.V. Kamal is the Head of the Department for Emerging Technologies (CSE) at MRCET, overseeing IoT, Cybersecurity, and Data Science.",
    "He holds a B.E. (CSE), M.Tech (SE), and Ph.D.",
    "You can contact him at +91-7409262929 or via email at mvkamal@mrcet.ac.in and kamalmrcet@gmail.com."
  ],
  "context_set": ""
},

    #Ece hod
    {
  "tag": "MRCET_ECE_HOD",
  "patterns": [
    "HOD of ECE at MRCET",
    "Electronics and Communication Engineering HOD at MRCET",
    "ECE HOD at MRCET",
    "ECE HOD contact details",
    "ECE HOD",
    "ECE department head at MRCET",
    "Contact details of Dr. K. Mallikharjuna Lingam",
    "Who is the ECE HOD at MRCET"
  ],
  "responses": [
    "Dr. K. Mallikharjuna Lingam is the Head of the Department (HOD) for Electronics and Communication Engineering (ECE) at MRCET.",
    "He holds MIETE, M.Tech, and Ph.D. degrees.",
    "You can contact him at +91 9505237779 or via email at mallikarjunk24@gmail.com."
  ],
  "context_set": ""
},

    # EEE hod
    {
  "tag": "MRCET_EEE_HOD",
  "patterns": [
    "HOD of EEE at MRCET",
    "Electrical and Electronics Engineering HOD at MRCET",
    "EEE HOD at MRCET",
    "EEE HOD contact details",
    "EEE HOD",
    "EEE department head at MRCET",
    "Contact details of Dr. M. Sharanya",
    "Who is the EEE HOD at MRCET"
  ],
  "responses": [
    "Dr. M. Sharanya is the Head of the Department (HOD) for Electrical and Electronics Engineering (EEE) at MRCET.",
    "She holds B.Tech, M.Tech, Ph.D., MISTE, MIE, and MIETE degrees.",
    "You can contact her at +91 9849248291 or via email at sharanya.mtsai@gmail.com."
  ],
  "context_set": ""
},


# IT hod
    {
  "tag": "MRCET_IT_HOD",
  "patterns": [
    "HOD of IT at MRCET",
    "Information Technology HOD at MRCET",
    "IT HOD at MRCET",
    "IT HOD contact details",
    "IT HOD",
    "IT department head at MRCET",
    "Contact details of Dr. G. Sharada",
    "Who is the IT HOD at MRCET"
  ],
  "responses": [
    "Dr. G. Sharada is the Head of the Department (HOD) for Information Technology (IT) at MRCET.",
    "She holds M.Tech, Ph.D., MISTE, and MCSI degrees.",
    "You can contact her at +91 9849175249 or via email at gsharada8@gmail.com."
  ],
  "context_set": ""
},


    #mech HOD
    {
  "tag": "MRCET_Mechanical_HOD",
  "patterns": [
    "HOD of Mechanical at MRCET",
    "Mechanical Engineering HOD at MRCET",
    "Mechanical HOD at MRCET",
    "Mechanical HOD contact details",
    "Mechanical HOD",
    "Mech HOD",
    "Mechanical department head at MRCET",
    "Contact Dr. Srikar Potnuru at MRCET",
    "Who is the head of Mechanical department at MRCET",
    "MRCET Mechanical department contact"
  ],
  "responses": [
    "Dr. Srikar Potnuru is the Head of the Department (HOD) of Mechanical Engineering at MRCET.",
    "He is an Associate Professor in the Mechanical Engineering department.",
    "You can contact him at +91-70643-64314 or via email at srikarpotnuru@gmail.com."
  ],
  "context_set": ""
},

    # AERO HOd
    {
  "tag": "MRCET_Aeronautical_Engineering_HOD",
  "patterns": [
    "Who is the HOD of Aeronautical Engineering at MRCET",
    "HOD of Aeronautical Engineering at MRCET",
    "Aeronautical Engineering HOD at MRCET",
    "Aeronautical Engineering HOD contact details",
    "Aeronautical Engineering HOD",
    "Aero Hod",
    "Aeronautical Engineering department head at MRCET",
    "Contact Dr. M. Mohammed Mohaideen at MRCET",
    "MRCET Aeronautical Engineering department contact",
    "Aeronautical Engineering HOD details at MRCET"
  ],
  "responses": [
    "Dr. M. Mohammed Mohaideen is the Head of the Department for Aeronautical Engineering at MRCET.",
    "He holds B.E. (Mech), M.E. (Aero), Ph.D. (Aero), and MBA (HR).",
    "You can contact him at +91-7373369629 or via email at mohdmohaideen16@gmail.com."
  ],
  "context_set": ""
}












    ]
}

# %% [markdown]
# ### Downloading NLP Package

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# # Processing Data and Synonym Augmentation for Intent Classification

# %%
stemmer = WordNetLemmatizer()

words = []
classes = []
documents = []
ignore_words = ['?']


for intent in intents['intents']:
    for pattern in intent['patterns']:
        # Tokenize each word in the sentence
        w = nltk.word_tokenize(pattern)
        # Add to our words list
        words.extend(w)
        # Add to documents in our corpus
        documents.append((w, intent['tag']))
        # Add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])


words = [stemmer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))


classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)
# Out:
# 276 documents
# ...

# %%
training = []
output = []
output_empty = [0] * len(classes)

# Training set, bag of words for each sentence
for doc in documents:
    # Initialize our bag of words
    bag = []
    # List of tokenized words for the pattern
    pattern_words = doc[0]
    # Lemmatize each word
    pattern_words = [stemmer.lemmatize(word.lower()) for word in pattern_words]
    # Create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # Output is a '0' for each tag and '1' for the current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

random.shuffle(training)


def synonym_replacement(tokens, limit):
    augmented_sentences = []
    for i in range(len(tokens)):
        synonyms = []
        for syn in wordnet.synsets(tokens[i]):
            for lemma in syn.lemmas():
                synonyms.append(lemma.name())
        if len(synonyms) > 0:
            num_augmentations = min(limit, len(synonyms))
            sampled_synonyms = random.sample(synonyms, num_augmentations)
            for synonym in sampled_synonyms:
                augmented_tokens = tokens[:i] + [synonym] + tokens[i + 1:]
                augmented_sentences.append(' '.join(augmented_tokens))
    return augmented_sentences


# Augment the training data using synonym replacement
augmented_data = []
limit_per_tag = 100

for i, doc in enumerate(training):
    bag, output_row = doc
    tokens = [words[j] for j in range(len(words)) if bag[j] == 1]
    augmented_sentences = synonym_replacement(tokens, limit_per_tag)
    for augmented_sentence in augmented_sentences:
        # Ensure augmented_bag has the same length as words
        augmented_bag = [1 if word in augmented_sentence.split() else 0 for word in words]
        augmented_data.append([augmented_bag, output_row])

# Convert lists to NumPy arrays
training = np.array(training, dtype=object)
augmented_data = np.array(augmented_data, dtype=object)

combined_data = np.concatenate((training, augmented_data), axis=0)
random.shuffle(combined_data)

# %% [markdown]
# # Splitting the Dataset

# %%
from sklearn.model_selection import train_test_split


def separate_data_by_tags(data):
    data_by_tags = {}
    for d in data:
        tag = tuple(d[1])
        if tag not in data_by_tags:
            data_by_tags[tag] = []
        data_by_tags[tag].append(d)
    return data_by_tags.values()


separated_data = separate_data_by_tags(combined_data)

# Lists to store training and testing data
training_data = []
testing_data = []

# Split each tag's data into training and testing sets
for tag_data in separated_data:
    train_data, test_data = train_test_split(tag_data, test_size=0.2, random_state=42)
    training_data.extend(train_data)
    testing_data.extend(test_data)


random.shuffle(training_data)
random.shuffle(testing_data)

# Convert training and testing data back to np.array
train_x = np.array([d[0] for d in training_data])
train_y = np.array([d[1] for d in training_data])
test_x = np.array([d[0] for d in testing_data])
test_y = np.array([d[1] for d in testing_data])

# %% [markdown]
# # Training The Model

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.dropout1 = nn.Dropout(0.2)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.dropout2 = nn.Dropout(0.2)

        self.fc3 = nn.Linear(hidden_size, output_size)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.bn1(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.relu2(x)
        x = self.bn2(x)
        x = self.dropout2(x)

        x = self.fc3(x)
        output = self.softmax(x)
        return output

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return self.softmax(x)

class CustomDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

def accuracy(predictions, targets):
    predicted_labels = torch.argmax(predictions, dim=1)
    true_labels = torch.argmax(targets, dim=1)
    correct = (predicted_labels == true_labels).sum().item()
    total = targets.size(0)
    return correct / total

def test_model(model, test_loader, criterion):
    model.eval()
    total_loss = 0.0
    total_accuracy = 0.0
    num_batches = len(test_loader)

    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)
            total_accuracy += accuracy(outputs, targets) * inputs.size(0)

    average_loss = total_loss / len(test_loader.dataset)
    average_accuracy = total_accuracy / len(test_loader.dataset)
    return average_loss, average_accuracy

# %%
# Create DataLoader for training and testing data
train_x = torch.tensor(train_x).float()
train_y = torch.tensor(train_y).float()
test_x = torch.tensor(test_x).float()
test_y = torch.tensor(test_y).float()

batch_size = 64
train_dataset = CustomDataset(train_x, train_y)
test_dataset = CustomDataset(test_x, test_y)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define the model, loss function, and optimizer
input_size = len(train_x[0])
hidden_size = 8
output_size = len(train_y[0])
model = NeuralNetwork(input_size, hidden_size, output_size)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters())

# Train the model and evaluate on the testing set
num_epochs = 50
for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for inputs, targets in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Update statistics
        running_loss += loss.item() * inputs.size(0)
        running_acc += accuracy(outputs, targets) * inputs.size(0)

    # Calculate average training loss and accuracy for the epoch
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = running_acc / len(train_loader.dataset)

    # Print training loss and accuracy for each epoch
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_acc:.4f}")

    # Evaluate on the testing set
    test_loss, test_accuracy = test_model(model, test_loader, criterion)
    print(f"Epoch [{epoch+1}/{num_epochs}], Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.4f}")

# Save the trained model
torch.save(model.state_dict(), 'model.pth')
# Out:
# Epoch [1/50], Training Loss: 0.0987, Training Accuracy: 0.0933
# Epoch [1/50], Testing Loss: 0.0933, Testing Accuracy: 0.1637
# Epoch [2/50], Training Loss: 0.0808, Training Accuracy: 0.2638
# Epoch [2/50], Testing Loss: 0.0688, Testing Accuracy: 0.3322
# Epoch [3/50], Training Loss: 0.0600, Training Accuracy: 0.4216
# Epoch [3/50], Testing Loss: 0.0516, Testing Accuracy: 0.5212
# Epoch [4/50], Training Loss: 0.0439, Training Accuracy: 0.6362
# Epoch [4/50], Testing Loss: 0.0368, Testing Accuracy: 0.7171
# Epoch [5/50], Training Loss: 0.0307, Training Accuracy: 0.7772
# Epoch [5/50], Testing Loss: 0.0258, Testing Accuracy: 0.8244
# Epoch [6/50], Training Loss: 0.0217, Training Accuracy: 0.8586
# Epoch [6/50], Testing Loss: 0.0187, Testing Accuracy: 0.8924
# Epoch [7/50], Training Loss: 0.0160, Training Accuracy: 0.9119
# Epoch [7/50], Testing Loss: 0.0142, Testing Accuracy: 0.9224
# Epoch [8/50], Training Loss: 0.0123, Training Accuracy: 0.9351
# ...

# %% [markdown]
# # Model Inference

# %%
def load_model(model_path, input_size, hidden_size, output_size):
    model = NeuralNetwork(input_size, hidden_size, output_size)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

# Function to preprocess the input sentence
def preprocess_sentence(sentence, words):
    sentence_words = sentence.lower().split()
    sentence_words = [word for word in sentence_words if word in words]
    return sentence_words

# Function to convert the preprocessed sentence into a feature vector
def sentence_to_features(sentence_words, words):
    features = [1 if word in sentence_words else 0 for word in words]
    return torch.tensor(features).float().unsqueeze(0)

# Function to generate a response using the trained model
def generate_response(sentence, model, words, classes):
    sentence_words = preprocess_sentence(sentence, words)
    if len(sentence_words) == 0:
        return "I'm sorry, but I don't understand. Can you please rephrase or provide more information?"

    features = sentence_to_features(sentence_words, words)
    with torch.no_grad():
        outputs = model(features)

    probabilities, predicted_class = torch.max(outputs, dim=1)
    confidence = probabilities.item()
    predicted_tag = classes[predicted_class.item()]

    if confidence > 0.5:
        for intent in intents['intents']:
            if intent['tag'] == predicted_tag:
                return random.choice(intent['responses'])

    return "I'm sorry, but I'm not sure how to respond to that."

# %%
import os

# ... other code ...

def load_model(model_path, input_size, hidden_size, output_size):
    # Get the absolute path to the model file
    model_path = os.path.abspath(model_path)

    # Print the path to verify if it's correct
    print(f"Loading model from: {model_path}")

    model = NeuralNetwork(input_size, hidden_size, output_size)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model
model_path = 'model.pth'
input_size = len(words)
hidden_size = 8
output_size = len(classes)
model = load_model(model_path, input_size, hidden_size, output_size)

# Test the chatbot response
print('Hello! I am a chatbot. How can I help you today? Type "quit" to exit.')
while True:
    user_input = input('> ')
    if user_input.lower() == 'quit':
        break
    response = generate_response(user_input, model, words, classes)
    print(response)
# Out:
# Loading model from: /content/model.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b9a83ad93fd1> in <cell line: 20>()
#      18 hidden_size = 8
#      19 output_size = len(classes)
# ---> 20 model = load_model(model_path, input_size, hidden_size, output_size)
#      21
#      22 # Test the chatbot response
#
# <ipython-input-13-b9a83ad93fd1> in load_model(model_path, input_size, hidden_size, output_size)
#      11
#      12     model = NeuralNetwork(input_size, hidden_size, output_size)
# ---> 13     model.load_state_dict(torch.load(model_path))
#      14     model.eval()
#      15     return model
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1063         pickle_load_args['encoding'] = 'utf-8'
#    1064
# ...

# %%
import textwrap

test_cases = [

    "Hello",
    "Good Morning",
    "Who is the principal of MRCET?",
    "Can you tell me about Dr. S Srinivasa Rao?",
    "What are the qualifications of the principal?",
    "who is Dean of Mrcet?",
    "Who is the dean of student welfare?",
    "Tell me about Dr. Tipirneni Venugopal?.",
    "What are the college timings for MRCET?",
    "What are the class sizes like?",
    "Does your major require an independent study?",
    "Are professors available for research with students?",
    "Are there study abroad programs available?",
    "What's it like to be a first-year student here?",
    "Can students spend a semester abroad?",
    "aiml hod?",
    "How can I get involved in research at your college?",
    "Tell me about the extracurricular activities on campus?.",
    "What resources are available for career counseling and job placement?",
    "Does the school offer any scholarships or financial aid for international students?",
    "How does the campus support students with disabilities?",
    "Are there any on-campus housing options for upperclassmen?",
    "What opportunities are there for students interested in community service and volunteering?",
    "Is there a mentoring program for freshmen to help with their transition to college life?",
    "What type of on-campus dining options are available?",
    "Tell me about the campus safety measures and security services?.",
    "What type of technology and computer facilities are accessible to students?",
    "Are there any notable guest speakers or events that regularly occur on campus?",
    "How does the college foster a sense of community and inclusivity among students?",
    "What is the average student-to-faculty ratio at the university?",
    "Can students participate in sports or fitness activities even if they are not part of a varsity team?",
    "Are there any unique academic programs or centers of excellence at the college?",
    "What type of student organizations are available for students to join?",
    "Tell me about the college's commitment to sustainability and environmental initiatives.",
    "How does the college handle academic support and tutoring for students who need extra help?",
    "Are there any opportunities for students to showcase their artistic talents, such as theater performances or art exhibitions?",
    "Does the college have any partnerships with local businesses or organizations for internships and experiential learning?",
    "What are the on-campus recreational facilities, such as fitness centers or sports fields?",
    "What are the admission requirements for international students?",
    "Can you tell me about the campus facilities, such as the library and student center?",
    "What types of student support services are available, such as counseling and health services?",
    "How diverse is the student body on campus?",
    "What are the top academic programs offered at the college?",
    "Does the college have any special programs for first-generation college students?",
    "What is the college's policy on AP credits and advanced placement?",
    "Are there opportunities for undergraduate students to participate in research with faculty?",
    "What kind of financial aid packages are available for low-income students?",
    "Can you provide information on the college's alumni network and career connections?",
    "Tell me about the college's approach to experiential learning and internships.",
    "What are the campus housing options for students who prefer a single room?",
    "Does the college offer any honors or honors programs for high-achieving students?",
    "What is the admission procedure for foreign students?",
    "How can foreign students apply?",
    "What are the seats reserved for foreign students?",
    "What is the eligibility criteria for B.Tech?",
    "What are the postgraduate courses offered at MRCET?",
    "Can you provide details about the MBA program at MRCET?",
    "What are the research programs offered at MRCET?",
    "What is the intake for B.Tech – Computer Science and Engineering?",
    "How many seats are available for B.Tech – Computer Science and Engineering (Artificial Intelligence and Machine Learning)?",
    "What is the intake capacity for B.Tech – Computer Science and Engineering (Data Science)?",
    "Can you tell me the intake for B.Tech – Computer Science and Engineering (Cyber Security)?",
    "How many seats are there for B.Tech – Computer Science and Information Technology?",
    "What is the seat intake for B.Tech – Electronics and Communication Engineering?",
    "How many students can enroll in B.Tech – Electrical and Electronics Engineering?",
    "What is the intake for B.Tech – Aeronautical Engineering?",
    "What is the number of seats for B.Tech – Mechanical Engineering?",
    "What is the intake for M.Tech – Computer Science and Engineering?",
    "How many seats are available for M.Tech – VLSI and Embedded Systems?",
    "What is the intake capacity for M. Tech – Aerospace Engineering?",
    "Can you tell me the intake for M.Tech – Machine Design?",
    "How many seats are there for M.Tech – Thermal Engineering?",
    "What is the intake for MBA – Master of Business Administration?",
    "Is there a Ph.D. course available in Electronics and Communication Engineering?",
    "What Ph.D. programs does MRCET offer?",
    "What are the hostel facilities available at MRCET?",
    "Does MRCET provide separate hostels for boys and girls?",
    "What dining services are available at the MRCET hostel?",
    "Is there a purified water system in the hostel at MRCET?",
    "Are medical and ambulance services available at the MRCET hostel?",
    "What security measures are there at MRCET hostels?",
    "Is there power backup in the MRCET hostels?",
    "What sports facilities are available in MRCET hostels?",
    "Does the MRCET hostel have a TV room?",
    "Are Wi-Fi services available in MRCET hostels?",
    "How is cleanliness maintained in the MRCET hostels?",
    "Does MRCET provide transport facilities?",
    "What is the transport fee at MRCET?",
    "How do I reach MRCET by bus?",
    "What bus routes are available for MRCET?",
    "What are the library facilities at MRCET?",
    "What kind of books are available at MRCET library?",
    "What are the working hours of the MRCET library?",
    "Does MRCET library provide multiple copies of books?",
    "What sports facilities are available at MRCET?",
    "Does MRCET have a gymnasium?",
    "What games can students play at MRCET sports center?",
    "Is there a basketball court at MRCET?",
    "Does MRCET provide cricket facilities?",
    "What traditional sports are offered at MRCET?",
    "Are there facilities for indoor games at MRCET?",
    "What indoor games are available at MRCET?",
    "Is there a facility for athletes at MRCET?",
    "Does MRCET offer badminton courts?",
    "Can students play football at MRCET?",

    # Placement Statistics
    "What are the UG placement statistics at MRCET?",
    "What are the PG placement statistics at MRCET?",
    "Can you provide placement details at MRCET?",
    "What is the median salary package for UG students at MRCET?",
    "What is the median salary package for PG students at MRCET?",
    "How many UG students opted for higher studies at MRCET?",
    "How many PG students opted for higher studies at MRCET?",
    "What is the average salary package for UG students at MRCET?",
    "What is the average salary package for PG students at MRCET?",

    # Top Recruiters
    "Who are the top recruiters at MRCET?",
    "What companies hire from MRCET?",
    "Can you list the recruiters at MRCET Hyderabad?",
    "What are the top companies for placements at MRCET?",

    # Placement Records
    "What is the history of placement at MRCET?",
    "Where can I find the top placement sheet at MRCET?",
    "Are there placement records available for MRCET students?",

    # HODs
    # Humanities and Sciences HOD
    "Who is the HOD of Humanities & Sciences at MRCET?",
    "What are the contact details for the HOD of H&S at MRCET?",

    # CSE AIML HOD
    "aiml hod?",
    "Who is the HOD of CSE AIML?",
    "Who is the HOD of CSE AIML at MRCET?",
    "What are the contact details for the HOD of AIML at MRCET?",

    # Emerging Technologies HOD
    "Who is the HOD of IoT and Cybersecurity at MRCET?",
    "What are the contact details for the HOD of Emerging Technologies at MRCET?",

    # ECE HOD
    "Who is the HOD of ECE at MRCET?",
    "What are the contact details for the HOD of ECE at MRCET?",

    # EEE HOD
    "Who is the HOD of EEE at MRCET?",
    "What are the contact details for the HOD of EEE at MRCET?",

    # IT HOD
    "Who is the HOD of IT at MRCET?",
    "What are the contact details for the HOD of IT at MRCET?",

    # Mechanical HOD
    "Who is the HOD of Mechanical Engineering at MRCET?",
    "What are the contact details for the HOD of Mechanical Engineering at MRCET?",

    # Aeronautical Engineering HOD
    "Who is the HOD of Aeronautical Engineering at MRCET?",
    "What are the contact details for the HOD of Aeronautical Engineering at MRCET?"
]




print('Testing Cases starting..........\n')

unseen = []
for i in test_cases:
  print(i)
  print('\n')
  text = generate_response(i.lower(),model, words, classes)
  print(textwrap.fill(text, width=70))
  print('-------------------------------------')
  if text == "I'm sorry, but I'm not sure how to respond to that.":
    unseen.append(i)
# Out:
# Testing Cases starting..........
#
# Hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-18d8df1fa9f1> in <cell line: 175>()
#     176   print(i)
#     177   print('\n')
# --> 178   text = generate_response(i.lower(),model, words, classes)
#     179   print(textwrap.fill(text, width=70))
#     180   print('-------------------------------------')
#
# NameError: name 'model' is not defined

# %%
unseen
# Out:
# ['What are the qualifications of the principal?',
#  'What are the class sizes like?',
#  'Does the school offer any scholarships or financial aid for international students?',
#  'Are there any on-campus housing options for upperclassmen?',
#  'What opportunities are there for students interested in community service and volunteering?',
#  'What type of on-campus dining options are available?',
#  'What is the average student-to-faculty ratio at the university?',
#  "Tell me about the college's commitment to sustainability and environmental initiatives.",
#  'Are there any opportunities for students to showcase their artistic talents, such as theater performances or art exhibitions?',
#  'Does the college have any partnerships with local businesses or organizations for internships and experiential learning?',
#  'Does MRCET provide separate hostels for boys and girls?',
#  'How is cleanliness maintained in the MRCET hostels?',
# ...
